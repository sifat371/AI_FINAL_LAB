# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# 1. Load Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# 2. Model Builder
def build_model(activation='relu', loss_fn='categorical_crossentropy'):
    model = models.Sequential([
        layers.Input(shape=(32,32,3)),
        layers.Conv2D(32, (3,3), activation=activation),
        layers.MaxPooling2D(2,2),
        layers.Conv2D(64, (3,3), activation=activation),
        layers.MaxPooling2D(2,2),
        layers.Flatten(),
        layers.Dense(128, activation=activation),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=loss_fn,
        metrics=['accuracy']
    )
    return model

# 3. Experiments
configs = [
    ('relu', 'categorical_crossentropy'),
    ('tanh', 'categorical_crossentropy'),
    ('relu', 'mean_squared_error'),
]

for act, loss in configs:
    print(f"\nTraining with Activation={act}, Loss={loss}")
    model = build_model(act, loss)

    if loss == 'categorical_crossentropy':
        model.fit(x_train, y_train_cat, epochs=5,
                  validation_data=(x_test, y_test_cat), batch_size=64)
    else:
        model.fit(x_train, y_train_cat, epochs=5,
                  validation_data=(x_test, y_test_cat), batch_size=64)

    test_loss, test_acc = model.evaluate(x_test, y_test_cat)
    print("Test Accuracy:", test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#
# Training with Activation=relu, Loss=categorical_crossentropy
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.3704 - loss: 1.7285 - val_accuracy: 0.5747 - val_loss: 1.2256
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5840 - loss: 1.1867 - val_accuracy: 0.6184 - val_loss: 1.0888
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6430 - loss: 1.0274 - val_accuracy: 0.6486 - val_loss: 1.0096
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6750 - loss: 0.9315 - val_accuracy: 0.6797 - val_loss: 0.9339
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7127 - loss: 0.8357 - val_accuracy: 0.6686 - val_loss: 0.9592
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6721 - loss: 0.9486
# Test Accuracy: 0.6686000227928162
#
# Training with Activation=tanh, Loss=categorical_crossentropy
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.4290 - loss: 1.6162 - val_accuracy: 0.5841 - val_loss: 1.2007
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6089 - loss: 1.1348 - val_accuracy: 0.6302 - val_loss: 1.0872
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6545 - loss: 0.9888 - val_accuracy: 0.6415 - val_loss: 1.0462
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6948 - loss: 0.8756 - val_accuracy: 0.6711 - val_loss: 0.9595
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7314 - loss: 0.7764 - val_accuracy: 0.6745 - val_loss: 0.9514
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6784 - loss: 0.9366
# Test Accuracy: 0.6744999885559082
#
# Training with Activation=relu, Loss=mean_squared_error
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.3654 - loss: 0.0747 - val_accuracy: 0.5473 - val_loss: 0.0588
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5791 - loss: 0.0553 - val_accuracy: 0.6201 - val_loss: 0.0506
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6420 - loss: 0.0483 - val_accuracy: 0.6595 - val_loss: 0.0462
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6827 - loss: 0.0435 - val_accuracy: 0.6825 - val_loss: 0.0436
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7130 - loss: 0.0397 - val_accuracy: 0.6830 - val_loss: 0.0432
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6821 - loss: 0.0434
# Test Accuracy: 0.6830000281333923
