# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


# -------- MODEL --------
def build_fcf_nn(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Flatten()(inputs)
    x = Dense(512, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model


# -------- TRAIN FUNCTION --------
def run_dataset(dataset_name):
    if dataset_name == "mnist":
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

    elif dataset_name == "fashion":
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    elif dataset_name == "cifar":
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Normalize
    x_train = x_train / 255.0
    x_test = x_test / 255.0

    # One-Hot
    y_train = to_categorical(y_train, 10)
    y_test = to_categorical(y_test, 10)

    model = build_fcf_nn(x_train.shape[1:], 10)

    model.fit(x_train, y_train,
              validation_split=0.1,
              epochs=10,
              batch_size=128)

    loss, acc = model.evaluate(x_test, y_test)
    print(f"{dataset_name} Test Accuracy:", acc)


# -------- MAIN --------
run_dataset("mnist")
run_dataset("fashion")
run_dataset("cifar")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8643 - loss: 0.4606 - val_accuracy: 0.9697 - val_loss: 0.0980
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9723 - loss: 0.0918 - val_accuracy: 0.9765 - val_loss: 0.0820
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9829 - loss: 0.0562 - val_accuracy: 0.9810 - val_loss: 0.0683
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9898 - loss: 0.0337 - val_accuracy: 0.9772 - val_loss: 0.0803
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9918 - loss: 0.0257 - val_accuracy: 0.9790 - val_loss: 0.0804
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9917 - loss: 0.0244 - val_accuracy: 0.9818 - val_loss: 0.0755
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9926 - loss: 0.0198 - val_accuracy: 0.9807 - val_loss: 0.0785
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9939 - loss: 0.0184 - val_accuracy: 0.9832 - val_loss: 0.0731
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9949 - loss: 0.0144 - val_accuracy: 0.9815 - val_loss: 0.0782
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9957 - loss: 0.0122 - val_accuracy: 0.9800 - val_loss: 0.0898
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9777 - loss: 0.0989
# mnist Test Accuracy: 0.9800000190734863
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.7641 - loss: 0.6740 - val_accuracy: 0.8495 - val_loss: 0.4179
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8633 - loss: 0.3750 - val_accuracy: 0.8640 - val_loss: 0.3639
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.8787 - loss: 0.3222 - val_accuracy: 0.8798 - val_loss: 0.3371
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8878 - loss: 0.3026 - val_accuracy: 0.8728 - val_loss: 0.3526
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8941 - loss: 0.2810 - val_accuracy: 0.8773 - val_loss: 0.3398
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9013 - loss: 0.2644 - val_accuracy: 0.8838 - val_loss: 0.3148
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9054 - loss: 0.2492 - val_accuracy: 0.8830 - val_loss: 0.3225
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9120 - loss: 0.2404 - val_accuracy: 0.8942 - val_loss: 0.2967
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9154 - loss: 0.2253 - val_accuracy: 0.8873 - val_loss: 0.3155
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9177 - loss: 0.2170 - val_accuracy: 0.8880 - val_loss: 0.3274
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8875 - loss: 0.3425
# fashion Test Accuracy: 0.8873999714851379
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.2525 - loss: 2.0636 - val_accuracy: 0.3638 - val_loss: 1.7746
# Epoch 2/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.3805 - loss: 1.7225 - val_accuracy: 0.4054 - val_loss: 1.6908
# Epoch 3/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4173 - loss: 1.6244 - val_accuracy: 0.4390 - val_loss: 1.5951
# Epoch 4/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.4504 - loss: 1.5401 - val_accuracy: 0.4380 - val_loss: 1.5697
# Epoch 5/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4628 - loss: 1.5071 - val_accuracy: 0.4650 - val_loss: 1.5050
# Epoch 6/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.4777 - loss: 1.4683 - val_accuracy: 0.4698 - val_loss: 1.4812
# Epoch 7/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.4902 - loss: 1.4290 - val_accuracy: 0.4824 - val_loss: 1.4703
# Epoch 8/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.5033 - loss: 1.3947 - val_accuracy: 0.4754 - val_loss: 1.4618
# Epoch 9/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.5137 - loss: 1.3619 - val_accuracy: 0.4886 - val_loss: 1.4408
# Epoch 10/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.5241 - loss: 1.3514 - val_accuracy: 0.5018 - val_loss: 1.4255
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5010 - loss: 1.4170
# cifar Test Accuracy: 0.4975999891757965
